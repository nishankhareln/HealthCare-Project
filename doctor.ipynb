# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv('doctors.csv')
df.head(5)
# Out:
#        hospital                name department  \
# 0  B&B Hospital   Dr. Ajit Shrestha        NaN
# 1  B&B Hospital  Dr. Amit Man Joshi        NaN
# 2  B&B Hospital   Dr. Ananda Khanal        NaN
# 3  B&B Hospital   Dr. Anil Shrestha        NaN
# 4  B&B Hospital    Dr. Anjana Karki        NaN
#
#                                            position  \
# 0                                 Senior Consultant
# 1                     Consultant Gastroenterologist
# 2                           Consultant Cardiologist
# 3  Consultant Urologist & Kidney Transplant Surgeon
# 4           Consultant Obstetrician & Gynaecologist
#
#                                          profile_url
# 0  https://bbhospital.com.np/HomeUI/OurDoctorDeta...
# 1  https://bbhospital.com.np/HomeUI/OurDoctorDeta...
# 2  https://bbhospital.com.np/HomeUI/OurDoctorDeta...
# 3  https://bbhospital.com.np/HomeUI/OurDoctorDeta...
# 4  https://bbhospital.com.np/HomeUI/OurDoctorDeta...
